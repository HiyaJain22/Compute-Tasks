# %% [markdown]
# <a href="https://colab.research.google.com/github/HiyaJain22/Compute-Tasks/blob/main/MLtask3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("/content/haberman.csv.xls")
df.head()
# Out:
#    30  64   1  1.1
# 0  30  62   3    1
# 1  30  65   0    1
# 2  31  59   2    1
# 3  31  65   4    1
# 4  33  58  10    1

# %%
df.columns = ['patient_age', 'operation_year', 'positive_axillary_nodes', 'survival_status']
df
# Out:
#      patient_age  operation_year  positive_axillary_nodes  survival_status
# 0             30              62                        3                1
# 1             30              65                        0                1
# 2             31              59                        2                1
# 3             31              65                        4                1
# 4             33              58                       10                1
# ..           ...             ...                      ...              ...
# 300           75              62                        1                1
# 301           76              67                        0                1
# 302           77              65                        3                1
# 303           78              65                        1                2
# 304           83              58                        2                2
#
# [305 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   patient_age              305 non-null    int64
#  1   operation_year           305 non-null    int64
#  2   positive_axillary_nodes  305 non-null    int64
#  3   survival_status          305 non-null    int64
# dtypes: int64(4)
# memory usage: 9.7 KB

# %%
df.isnull().sum()
# Out:
# patient_age                0
# operation_year             0
# positive_axillary_nodes    0
# survival_status            0
# dtype: int64

# %%
df['survival_status'].replace(2,0,inplace=True)
df
# Out:
#      patient_age  operation_year  positive_axillary_nodes  survival_status
# 0             30              62                        3                1
# 1             30              65                        0                1
# 2             31              59                        2                1
# 3             31              65                        4                1
# 4             33              58                       10                1
# ..           ...             ...                      ...              ...
# 300           75              62                        1                1
# 301           76              67                        0                1
# 302           77              65                        3                1
# 303           78              65                        1                0
# 304           83              58                        2                0
#
# [305 rows x 4 columns]

# %%
corr=df.corr()
corr
# Out:
#                          patient_age  operation_year  positive_axillary_nodes  \
# patient_age                 1.000000        0.092623                -0.066548
# operation_year              0.092623        1.000000                -0.003277
# positive_axillary_nodes    -0.066548       -0.003277                 1.000000
# survival_status            -0.064351        0.004076                -0.286191
#
#                          survival_status
# patient_age                    -0.064351
# operation_year                  0.004076
# positive_axillary_nodes        -0.286191
# survival_status                 1.000000

# %%
df.describe()
# Out:
#        patient_age  operation_year  positive_axillary_nodes  survival_status
# count   305.000000      305.000000               305.000000       305.000000
# mean     52.531148       62.849180                 4.036066         0.734426
# std      10.744024        3.254078                 7.199370         0.442364
# min      30.000000       58.000000                 0.000000         0.000000
# 25%      44.000000       60.000000                 0.000000         0.000000
# 50%      52.000000       63.000000                 1.000000         1.000000
# 75%      61.000000       66.000000                 4.000000         1.000000
# max      83.000000       69.000000                52.000000         1.000000

# %%
sns.heatmap(corr)

# %%
df[['patient_age','survival_status']].groupby(['patient_age']).mean()
# Out:
#              survival_status
# patient_age
# 30                  1.000000
# 31                  1.000000
# 33                  1.000000
# 34                  0.714286
# 35                  1.000000
# 36                  1.000000
# 37                  1.000000
# 38                  0.900000
# 39                  0.833333
# 40                  1.000000
# 41                  0.700000
# 42                  0.777778
# 43                  0.636364
# 44                  0.571429
# 45                  0.666667
# 46                  0.428571
# 47                  0.727273
# 48                  0.571429
# 49                  0.800000
# 50                  0.833333
# 51                  0.666667
# 52                  0.714286
# 53                  0.454545
# 54                  0.692308
# 55                  0.800000
# 56                  0.714286
# 57                  0.727273
# 58                  1.000000
# 59                  0.875000
# 60                  0.666667
# ...

# %%
sns.scatterplot(x=df.patient_age,y=df.survival_status)

# %%
sns.countplot(x=df.patient_age)

# %%
pd.crosstab(df.patient_age,df.survival_status,margins=True)
# Out:
# survival_status   0    1  All
# patient_age
# 30                0    2    2
# 31                0    2    2
# 33                0    2    2
# 34                2    5    7
# 35                0    2    2
# 36                0    2    2
# 37                0    6    6
# 38                1    9   10
# 39                1    5    6
# 40                0    3    3
# 41                3    7   10
# 42                2    7    9
# 43                4    7   11
# 44                3    4    7
# 45                3    6    9
# 46                4    3    7
# 47                3    8   11
# 48                3    4    7
# 49                2    8   10
# 50                2   10   12
# 51                2    4    6
# 52                4   10   14
# 53                6    5   11
# 54                4    9   13
# 55                2    8   10
# 56                2    5    7
# 57                3    8   11
# 58                0    7    7
# 59                1    7    8
# ...

# %%
df[['operation_year','survival_status']].groupby(['operation_year']).mean()
# Out:
#                 survival_status
# operation_year
# 58                     0.666667
# 59                     0.666667
# 60                     0.857143
# 61                     0.884615
# 62                     0.695652
# 63                     0.733333
# 64                     0.733333
# 65                     0.535714
# 66                     0.785714
# 67                     0.840000
# 68                     0.769231
# 69                     0.636364

# %%
sns.scatterplot(x=df.operation_year,y=df.patient_age)

# %%
df[['positive_axillary_nodes','survival_status']].groupby(['positive_axillary_nodes']).mean()
# Out:
#                          survival_status
# positive_axillary_nodes
# 0                               0.860294
# 1                               0.800000
# 2                               0.750000
# 3                               0.650000
# 4                               0.769231
# 5                               0.333333
# 6                               0.571429
# 7                               0.714286
# 8                               0.714286
# 9                               0.333333
# 10                              0.666667
# 11                              0.250000
# 12                              0.500000
# 13                              0.200000
# 14                              0.750000
# 15                              0.333333
# 16                              1.000000
# 17                              0.000000
# 18                              1.000000
# 19                              0.333333
# 20                              0.500000
# ...

# %%
sns.scatterplot(x=df.patient_age,y=df.positive_axillary_nodes)

# %%
sns.boxplot(data=df, x="survival_status", y="patient_age")

# %%
sns.boxplot(data=df, x="survival_status", y="operation_year")

# %%
sns.boxplot(data=df, x="survival_status", y="positive_axillary_nodes")
